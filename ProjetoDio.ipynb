# %% [markdown]
# <a href="https://colab.research.google.com/github/MarquinDj/LandingPage-FoodY-/blob/main/ProjetoDio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

notas_df = pd.read_csv("notas.csv")

# %%
notas_df
# Out:
#       Nome  Nota
# 0     João   8.5
# 1    Maria   7.2
# 2    Pedro   9.0
# 3      Ana   6.8
# 4    Luísa   8.9
# 5   Rafael   7.5
# 6    Carla   9.2
# 7   Miguel   6.0
# 8    Sofia   8.7
# 9  Gustavo   7.8

# %%
# !pip install bardapi

# %%
from bardapi import Bard
import os

# %%
os.environ['_BARD_API_KEY']='awiQ9KyXagKNGSwmh3aplC3eM9fNRwOBIxtNFAoCg9ZS7SycfIMJtYcYSxdTgdxu2LQ9Zw.'

# %%
def generate_message(aluno):
  mensagens = []
  for index, row in aluno.iterrows():
    aluno_nome = row['Nome']
    nota = row['Nota']
    input_text = f"Crie uma mensagem para o aluno {aluno_nome} sobre suas notas, se {nota} for maior que 7, o parabenize, se for menor, dê conselhos para melhorar (máximo 100 caracteres)"
    bard_output = Bard().get_answer(input_text)['content']
    mensagens.append(bard_output)
  return mensagens

# %%
aluno_mensagens = generate_message(notas_df)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-237-64f241da2a25> in <cell line: 1>()
# ----> 1 aluno_mensagens = generate_message(notas_df)
#
# <ipython-input-236-d4d730aa95b0> in generate_message(aluno)
#       5     nota = row['Nota']
#       6     input_text = f"Crie uma mensagem para o aluno {aluno_nome} sobre suas notas, se {nota} for maior que 7, o parabenize, se for menor, dê conselhos para melhorar (máximo 100 caracteres)"
# ----> 7     bard_output = Bard().get_answer(input_text)['content']
#       8     mensagens.append(bard_output)
#       9   return mensagens
#
# /usr/local/lib/python3.10/dist-packages/bardapi/core.py in __init__(self, token, timeout, proxies, session, conversation_id, google_translator_api_key, language, run_code, token_from_browser)
#      53         self.choice_id = ""
#      54         self.session = self._get_session(session)
# ...

# %%
for i, message in enumerate(aluno_mensagens):
    print(f"Aluno: {notas_df['Nome'][i]}, Mensagem: {message}")

# %%
notas_df['aluno_mensagens'] = aluno_mensagens
